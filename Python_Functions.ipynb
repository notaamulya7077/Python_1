# %% [markdown]
# <a href="https://colab.research.google.com/github/notaamulya7077/Python_1/blob/main/Python_Functions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# defining functions
def greet(first_name, last_name):
  print(f"Hi {first_name} {last_name}")
  print("Welcome aboard")


greet("Amulya", "Acharya")
greet("John", "Doe")
# Out:
# Hi Amulya Acharya
# Welcome aboard
# Hi John Doe
# Welcome aboard

# %%
def greet(name):
  print(f"Hi {name}")
print(greet("Amulya"))

# this function only returns value, can be used later without redefining function
def get_greeting(name):
  return f"Hi {name}"

message = get_greeting("Amulya")
# Out:
# Hi Amulya
# None

# %% [markdown]
# <a href="https://colab.research.google.com/github/notaamulya7077/Python_1/blob/main/Python_Operators.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
10 >= 3
# Out:
# True

# %%
10 <= 3
# Out:
# False

# %%
10 != "10"
# Out:
# True

# %%
10 == "10"
# Out:
# False

# %%
temperature = 15
if temperature > 30:
  print("It's warm")
  print("Drink water")
elif temperature > 20:
  print("It's nice")
else:
  print("It's cold")
print("Done")
# Out:
# It's cold
# Done

# %%
age = input("What is your age? ")
message = "Eligible" if int(age) >= 18 else "Not eligible"
print(message)
# Out:
# What is your age? 6
# Not eligible

# %%
high_income = False
good_credit = True
student = True

if high_income or good_credit or not student:
  print("Eligible")
else:
  print("Not eligible")
# Out:
# Eligible

# %%
# age should be between 18 and 65
age = 22
if age >= 18 < 65:
  print("Eligible")
else:
  print("Not eligible")
# Out:
# Eligible

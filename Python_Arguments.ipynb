# %% [markdown]
# <a href="https://colab.research.google.com/github/notaamulya7077/Python_1/blob/main/Python_Arguments.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def increment(number, by=1):
  return number + by

print(increment (2, 5))
# Out:
# 7
